# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("C:\\Users\\fried\\Downloads\\Projects\\Covid 19\\archive\\covid_19_clean_complete.csv")

# %%
data.tail(20)
# Out:
#                     Province/State         Country/Region        Lat  \
# 49048        Northwest Territories                 Canada  64.825500
# 49049                        Yukon                 Canada  64.282300
# 49050                          NaN                 Kosovo  42.602636
# 49051                          NaN                  Burma  21.916200
# 49052                     Anguilla         United Kingdom  18.220600
# 49053       British Virgin Islands         United Kingdom  18.420700
# 49054     Turks and Caicos Islands         United Kingdom  21.694000
# 49055                          NaN               Botswana -22.328500
# 49056                          NaN                Burundi  -3.373100
# 49057                          NaN           Sierra Leone   8.460555
# 49058                          NaN                 Malawi -13.254300
# 49059  Falkland Islands (Malvinas)         United Kingdom -51.796300
# 49060    Saint Pierre and Miquelon                 France  46.885200
# ...

# %%
data
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
data.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
data.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %% [markdown]
# # Relating Variables with Scatterplots

# %%
sns.relplot(x="WHO Region", y="Deaths", data=data)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Lat'}>,
#         <Axes: title={'center': 'Long'}>],
#        [<Axes: title={'center': 'Confirmed'}>,
#         <Axes: title={'center': 'Deaths'}>],
#        [<Axes: title={'center': 'Recovered'}>,
#         <Axes: title={'center': 'Active'}>]], dtype=object)

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
survival_by_class = data.groupby('Country/Region')['Recovered'].count()
survival_by_class.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Got saved')
plt.xlabel('might get saved')
plt.ylabel('actually got saved')
plt.show()
print(survival_by_class)
# Out:
# Country/Region
# Afghanistan           188
# Albania               188
# Algeria               188
# Andorra               188
# Angola                188
#                      ...
# West Bank and Gaza    188
# Western Sahara        188
# Yemen                 188
# Zambia                188
# Zimbabwe              188
# Name: Recovered, Length: 187, dtype: int64

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.countplot(x='WHO Region', data=data)
plt.title('Distribution')
plt.show()

# %%
sns.pairplot(data)
